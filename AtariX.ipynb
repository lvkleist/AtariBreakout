# %%
import random, numpy, math, gym, sys
from keras import backend as K

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
HUBER_LOSS_DELTA = 1.0
LEARNING_RATE = 0.00025

# %%
def to_grayscale(img):
    return np.mean(img, axis=2).astype(np.uint8)

def downsample(img):
    return img[::2, ::2]

def preprocess(img):
    return to_grayscale(downsample(img))

# %%
def huber_loss(y_true, y_pred):
    err = y_true - y_pred

    cond = K.abs(err) < HUBER_LOSS_DELTA
    L2 = 0.5 * K.square(err)
    L1 = HUBER_LOSS_DELTA * (K.abs(err) - 0.5 * HUBER_LOSS_DELTA)

    loss = tf.where(cond, L2, L1)   # Keras does not cover where function in tensorflow :-(
    #print(f'loss: {loss}')
    return K.mean(loss)

# %%
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import *

ATARI_SHAPE = (105, 80, 4)
class Brain:
    def __init__(self, stateCnt, actionCnt):
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt

        self.model = self._createModel()
        self.model_ = self._createModel() 

    def _createModel(self):
        model = Sequential()
        #model.add(Input(shape=ATARI_SHAPE))
        model.add(Lambda(lambda x: x/255.0, input_shape = ATARI_SHAPE))
        model.add(Conv2D(16, kernel_size = 8, activation='relu', strides = (4, 4)))
        model.add(Conv2D(32, kernel_size=4, activation='relu', strides = (2, 2)))
        model.add(Flatten())
        model.add(Dense(units=256, activation='relu'))
        model.add(Dense(units = actionCnt, activation='linear'))

        opt = RMSprop(lr=LEARNING_RATE)
        model.compile(loss=huber_loss, optimizer=opt)

        return model

    def train(self, x, y, epochs=1, verbose=0):
        self.model.fit(x, y, batch_size=64, epochs=epochs, verbose=verbose)
    def predict(self, s, target=False):
        #print(f'predict s shape: {s.shape}')
        if target:
            #print(f'target s shape: {s.shape}')
            return self.model_.predict(s)
        else:
            #print(f's shape in predict: {s.shape}')
            return self.model.predict(s)

    def predictOne(self, s, target=False):
        #pdb.setTrace()
        #print('predictOne: ')
        #print(f's shape: {s.shape}')
        s = np.stack([s, s, s, s], axis = 2)
        return self.predict(s.reshape(1, 105, 80, 4), target=target).flatten()

    def updateTargetModel(self):
        self.model_.set_weights(self.model.get_weights())

# %%
class Memory:   # stored as ( s, a, r, s_ )
    samples = []

    def __init__(self, capacity):
        self.capacity = capacity

    def add(self, sample):
        #print(f'memory-add s shape: {sample[0].shape}')
        self.samples.append(sample)        

        if len(self.samples) > self.capacity:
            self.samples.pop(0)

    def sample(self, n):
        n = min(n, len(self.samples))
        return random.sample(self.samples, n)

    def isFull(self):
        return len(self.samples) >= self.capacity

# %%
MEMORY_CAPACITY = 100000
BATCH_SIZE = 32
ATARI_SHAPE = (105, 80, 4)
GAMMA = 0.99

MAX_EPSILON = 1
MIN_EPSILON = 0.01
LAMBDA = 0.001      # speed of decay

UPDATE_TARGET_FREQUENCY = 1000

class Agent:
    steps = 0
    epsilon = MAX_EPSILON

    def __init__(self, stateCnt, actionCnt):
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt

        self.brain = Brain(stateCnt, actionCnt)
        self.memory = Memory(MEMORY_CAPACITY)
        
    def act(self, s):
        if random.random() < self.epsilon:
            return random.randint(0, self.actionCnt-1)
        else:
            return numpy.argmax(self.brain.predictOne(s))

    def printInfos(self):
        print(f' epsilon: {self.epsilon}')
        print(f' lenMemory: {len(self.memory.samples)}')
        print(f' capacityMemory: {self.memory.capacity}')
        print(f' steps: {self.steps}')
    
    def observe(self, sample):  # in (s, a, r, s_) format
        #print(f'observe s shape: {sample[0].shape}')
        self.memory.add(sample)        

        if self.steps % UPDATE_TARGET_FREQUENCY == 0:
            self.brain.updateTargetModel()

        # debug the Q function in poin S
        """"
        if self.steps % 100 == 0:
            S = numpy.random()
            pred = agent.brain.predictOne(S)
            print(pred[0])
            sys.stdout.flush()
        """
        # slowly decrease Epsilon based on our eperience
        self.steps += 1
        self.epsilon = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * math.exp(-LAMBDA * self.steps)
    def replay(self):    
        batch = self.memory.sample(BATCH_SIZE)
        batchLen = len(batch)
        #print(f'example batch element: {batch[0][0].shape}')
        
        #print(f'Batchlen: {batchLen}')
        no_state = numpy.zeros(ATARI_SHAPE)
        no_state_stack = np.stack([no_state, no_state, no_state, no_state], axis=2)
        states = numpy.array([ np.stack([o[0], o[0], o[0], o[0]], axis=2) for o in batch ])
        #print(f'Replay States: {states.shape}')
        states_ = numpy.array([ no_state if o[3] is None else np.stack([o[3], o[3], o[3], o[3]], axis=2) for o in batch ])
        #print(f'replay: states shape {states[0].shape}')
        #print(states)
        p = self.brain.predict(states)
        p_ = self.brain.predict(states_, target=True)

        x = numpy.zeros((batchLen, 105, 80, 4))
        y = numpy.zeros((batchLen, self.actionCnt))
        
        for i in range(batchLen):
            o = batch[i]
            s = o[0]; a = o[1]; r = o[2]; s_ = o[3]
            s = np.stack([o[0], o[0], o[0], o[0]], axis=2)
            if (s_  is not None):
                s_ = np.stack([o[3], o[3], o[3], o[3]], axis=2)
            t = p[i]
            if s_ is None:
                t[a] = r
            else:
                t[a] = r + GAMMA * numpy.amax(p_[i])
            #print(f'x shape: {x.shape}')
            x[i] = s
            y[i] = t

        self.brain.train(x, y)
class RandomAgent:
    memory = Memory(MEMORY_CAPACITY)

    def __init__(self, actionCnt):
        self.actionCnt = actionCnt

    def act(self, s):
        return random.randint(0, self.actionCnt-1)
    
    def printInfos(self):
        print(f' random: true')
        print(f' lenMemory: {len(self.memory.samples)}')
        print(f' capacityMemory: {self.memory.capacity}')
       
    

    def observe(self, sample):  # in (s, a, r, s_) format
        self.memory.add(sample)

    def replay(self):
        pass

# %%
class Environment:
    def __init__(self, problem):
        self.problem = problem
        self.env = gym.make(problem)

    def run(self, agent):
        s = self.env.reset()
        #print(f'Initial Environment s.shape 1: {s.shape}')
        s = preprocess(s)
        
        #print(f's shape: {s.shape}')
        #print(f's0 shape: {s[0].shape}')
        #print(f'Environment s.shape 2: {s.shape}')
        R = 0 
        numGames = 0
        while True:            
            # self.env.render()
            
            
            a = agent.act(s)
            #if(agent.memory.isFull()):
                #print(f'agent decided on action {a}')
            s_, r, done, info = self.env.step(a)
            s_ = preprocess(s_)
            if done: # terminal state
                s_ = None
                #print(f'Environment s.shape: {s.shape}')
            #if(agent.memory.isFull()):
                #print(f'about to call agent observe')
            agent.observe( (s, a, r, s_) )
            s = s_
            R += r
            
            #if(agent.memory.isFull()):
                #print(f'about to call agent replay')
            agent.replay()            

            

            if done:
                print(f'reward: {R}')
                agent.printInfos()
                break

# %%
PROBLEM = 'BreakoutDeterministic-v4'
env = Environment(PROBLEM)

stateCnt  = env.env.observation_space.shape[0]
actionCnt = env.env.action_space.n

agent = Agent(stateCnt, actionCnt)
randomAgent = RandomAgent(actionCnt)


try:
    while len(randomAgent.memory.samples) < 90000:
        env.run(randomAgent)
    print('memory full, broke out of while loop 1')
    agent.memory.samples = randomAgent.memory.samples
    randomAgent = None
    print('killed random agent')


    while True:
         #print('while loop 2')
         env.run(agent)

finally:
    agent.brain.model.save("cartpole-dqn.h5")
# Out:
# reward: 1.0
#  random: true
#  lenMemory: 179
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 378
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 566
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 713
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 911
#  capacityMemory: 100000
# reward: 4.0
#  random: true
#  lenMemory: 1212
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 1352
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 1495
#  capacityMemory: 100000
# reward: 5.0
#  random: true
#  lenMemory: 1800
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 1938
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 2071
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 2268
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 2401
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 2553
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 2691
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 2845
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 3050
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 3192
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 3326
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 3505
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 3643
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 3778
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 3939
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 4081
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 4230
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 4362
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 4538
#  capacityMemory: 100000
# reward: 3.0
#  random: true
#  lenMemory: 4797
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 4979
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 5121
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 5267
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 5434
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 5622
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 5834
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 5996
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 6200
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 6401
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 6578
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 6784
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 6912
#  capacityMemory: 100000
# reward: 3.0
#  random: true
#  lenMemory: 7165
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 7304
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 7471
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 7677
#  capacityMemory: 100000
# reward: 3.0
#  random: true
#  lenMemory: 7927
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 8117
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 8246
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 8475
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 8632
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 8834
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 9023
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 9161
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 9369
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 9552
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 9739
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 9962
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 10163
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 10299
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 10461
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 10600
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 10741
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 10950
#  capacityMemory: 100000
# reward: 4.0
#  random: true
#  lenMemory: 11259
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 11421
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 11604
#  capacityMemory: 100000
# reward: 4.0
#  random: true
#  lenMemory: 11910
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 12066
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 12265
#  capacityMemory: 100000
# reward: 3.0
#  random: true
#  lenMemory: 12512
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 12722
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 12868
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 13094
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 13230
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 13375
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 13513
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 13691
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 13922
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 14074
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 14217
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 14348
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 14481
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 14615
#  capacityMemory: 100000
# reward: 3.0
#  random: true
#  lenMemory: 14890
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 15040
#  capacityMemory: 100000
# reward: 3.0
#  random: true
#  lenMemory: 15275
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 15439
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 15642
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 15859
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 16082
#  capacityMemory: 100000
# reward: 4.0
#  random: true
#  lenMemory: 16385
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 16551
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 16689
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 16853
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 17024
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 17246
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 17472
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 17600
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 17737
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 17870
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 18076
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 18247
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 18373
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 18526
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 18741
#  capacityMemory: 100000
# reward: 5.0
#  random: true
#  lenMemory: 19087
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 19266
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 19408
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 19601
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 19734
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 19861
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 20080
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 20277
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 20494
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 20669
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 20826
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 20958
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 21131
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 21321
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 21539
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 21698
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 21939
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 22081
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 22265
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 22390
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 22529
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 22688
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 22849
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 22981
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 23118
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 23256
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 23464
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 23598
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 23766
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 23953
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory:
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 88038
#  capacityMemory: 100000
# reward: 4.0
#  random: true
#  lenMemory: 88363
#  capacityMemory: 100000
# reward: 2.0
#  random: true
#  lenMemory: 88577
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 88704
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 88848
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 88983
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 89148
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 89316
#  capacityMemory: 100000
# reward: 5.0
#  random: true
#  lenMemory: 89656
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 89789
#  capacityMemory: 100000
# reward: 1.0
#  random: true
#  lenMemory: 89951
#  capacityMemory: 100000
# reward: 0.0
#  random: true
#  lenMemory: 90100
#  capacityMemory: 100000
# memory full, broke out of while loop 1
# killed random agent
# reward: 1.0
#  epsilon: 0.8469002963378122
#  lenMemory: 90268
#  capacityMemory: 100000
#  steps: 168
# reward: 2.0
#  epsilon: 0.6924607000989802
#  lenMemory: 90472
#  capacityMemory: 100000
#  steps: 372
# reward: 2.0
#  epsilon: 0.5609835440663602
#  lenMemory: 90686
#  capacityMemory: 100000
#  steps: 586
# reward: 1.0
#  epsilon: 0.47904792237421007
#  lenMemory: 90847
#  capacityMemory: 100000
#  steps: 747
# reward: 1.0
#  epsilon: 0.40060817326788506
#  lenMemory: 91030
#  capacityMemory: 100000
#  steps: 930
# reward: 2.0
#  epsilon: 0.3288449527615792
#  lenMemory: 91233
#  capacityMemory: 100000
#  steps: 1133
# reward: 1.0
#  epsilon: 0.2765881459969255
#  lenMemory: 91412
#  capacityMemory: 100000
#  steps: 1312
# reward: 1.0
#  epsilon: 0.2267414011492558
#  lenMemory: 91619
#  capacityMemory: 100000
#  steps: 1519
# reward: 1.0
#  epsilon: 0.18341801351642734
#  lenMemory: 91842
#  capacityMemory: 100000
#  steps: 1742
# reward: 1.0
#  epsilon: 0.14875432774965722
#  lenMemory: 92065
#  capacityMemory: 100000
#  steps: 1965
# reward: 0.0
#  epsilon: 0.12566579360059849
#  lenMemory: 92247
#  capacityMemory: 100000
#  steps: 2147
# reward: 2.0
#  epsilon: 0.09865078992895567
#  lenMemory: 92513
#  capacityMemory: 100000
#  steps: 2413
# reward: 0.0
#  epsilon: 0.08584599805736856
#  lenMemory: 92669
#  capacityMemory: 100000
#  steps: 2569
# reward: 1.0
#  epsilon: 0.06772584209198138
#  lenMemory: 92942
#  capacityMemory: 100000
#  steps: 2842
# reward: 2.0
#  epsilon: 0.05433191928104303
#  lenMemory: 93206
#  capacityMemory: 100000
#  steps: 3106
# reward: 0.0
#  epsilon: 0.04518799393845256
#  lenMemory: 93437
#  capacityMemory: 100000
#  steps: 3337
# reward: 2.0
#  epsilon: 0.03601582334580009
#  lenMemory: 93739
#  capacityMemory: 100000
#  steps: 3639
# reward: 0.0
#  epsilon: 0.02962305093119859
#  lenMemory: 94021
#  capacityMemory: 100000
#  steps: 3921
# reward: 2.0
#  epsilon: 0.024683214096554544
#  lenMemory: 94311
#  capacityMemory: 100000
#  steps: 4211
# reward: 1.0
#  epsilon: 0.020619638154248193
#  lenMemory: 94635
#  capacityMemory: 100000
#  steps: 4535
# reward: 2.0
#  epsilon: 0.01755118831150685
#  lenMemory: 94976
#  capacityMemory: 100000
#  steps: 4876
# reward: 1.0
#  epsilon: 0.015056653713709503
#  lenMemory: 95377
#  capacityMemory: 100000
#  steps: 5277
# reward: 1.0
#  epsilon: 0.013776149890711084
#  lenMemory: 95669
#  capacityMemory: 100000
#  steps: 5569
# reward: 3.0
#  epsilon: 0.01275028610136944
#  lenMemory: 95986
#  capacityMemory: 100000
#  steps: 5886
# reward: 3.0
#  epsilon: 0.012021227384803844
#  lenMemory: 96294
#  capacityMemory: 100000
#  steps: 6194
# reward: 1.0
#  epsilon: 0.011644941700442194
#  lenMemory: 96500
#  capacityMemory: 100000
#  steps: 6400
# reward: 2.0
#  epsilon: 0.011232081410807025
#  lenMemory: 96789
#  capacityMemory: 100000
#  steps: 6689
# reward: 3.0
#  epsilon: 0.010907288264998889
#  lenMemory: 97095
#  capacityMemory: 100000
#  steps: 6995
# reward: 1.0
#  epsilon: 0.010742824804461355
#  lenMemory: 97295
#  capacityMemory: 100000
#  steps: 7195
# reward: 1.0
#  epsilon: 0.010622946239490137
#  lenMemory: 97471
#  capacityMemory: 100000
#  steps: 7371
# reward: 0.0
#  epsilon: 0.010474119889956512
#  lenMemory: 97744
#  capacityMemory: 100000
#  steps: 7644
# reward: 0.0
#  epsilon: 0.010360128251477455
#  lenMemory: 98019
#  capacityMemory: 100000
#  steps: 7919
# reward: 1.0
#  epsilon: 0.010284422333154106
#  lenMemory: 98255
#  capacityMemory: 100000
#  steps: 8155
# reward: 0.0
#  epsilon: 0.010215392128865297
#  lenMemory: 98533
#  capacityMemory: 100000
#  steps: 8433
# reward: 2.0
#  epsilon: 0.010172856232347557
#  lenMemory: 98753
#  capacityMemory: 100000
#  steps: 8653
# reward: 2.0
#  epsilon: 0.010137065679329395
#  lenMemory: 98985
#  capacityMemory: 100000
#  steps: 8885
# reward: 0.0
#  epsilon: 0.010112332162874011
#  lenMemory: 99184
#  capacityMemory: 100000
#  steps: 9084
# reward: 0.0
#  epsilon: 0.01009458134161689
#  lenMemory: 99356
#  capacityMemory: 100000
#  steps: 9256
# reward: 2.0
#  epsilon: 0.010075827439218485
#  lenMemory: 99577
#  capacityMemory: 100000
#  steps: 9477
# reward: 1.0
#  epsilon: 0.010058995444090009
#  lenMemory: 99828
#  capacityMemory: 100000
#  steps: 9728
# reward: 3.0
#  epsilon: 0.010046640078358463
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 9963
# reward: 3.0
#  epsilon: 0.01003082913616206
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 10377
# reward: 0.0
#  epsilon: 0.010021252195806673
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 10749
# reward: 3.0
#  epsilon: 0.010015838761926263
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 11043
# reward: 1.0
#  epsilon: 0.010011398254414154
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 11372
# reward: 0.0
#  epsilon: 0.010008868096930933
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 11623
# reward: 1.0
#  epsilon: 0.01000698287150174
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 11862
# reward: 3.0
#  epsilon: 0.010003255872282553
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 12625
# reward: 0.0
#  epsilon: 0.010002561159849531
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 12865
# reward: 1.0
#  epsilon: 0.010001744486463546
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 13249
# reward: 0.0
#  epsilon: 0.010001296230221383
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 13546
# reward: 0.0
#  epsilon: 0.01000105491502864
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 13752
# reward: 0.0
#  epsilon: 0.010000911612948204
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 13898
# reward: 1.0
#  epsilon: 0.010000631574243064
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 14265
# reward: 1.0
#  epsilon: 0.010000338734122786
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 14888
# reward: 2.0
#  epsilon: 0.010000258066034821
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps:
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 35699
# reward: 3.0
#  epsilon: 0.010000000000000252
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 35911
# reward: 5.0
#  epsilon: 0.010000000000000188
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 36202
# reward: 3.0
#  epsilon: 0.010000000000000151
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 36414
# reward: 3.0
#  epsilon: 0.010000000000000123
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 36626
# reward: 3.0
#  epsilon: 0.010000000000000099
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 36838
# reward: 3.0
#  epsilon: 0.01000000000000008
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 37048
# reward: 3.0
#  epsilon: 0.010000000000000066
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 37260
# reward: 3.0
#  epsilon: 0.010000000000000052
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 37472
# reward: 3.0
#  epsilon: 0.010000000000000044
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 37684
# reward: 3.0
#  epsilon: 0.010000000000000035
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 37896
# reward: 3.0
#  epsilon: 0.010000000000000028
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 38125
# reward: 3.0
#  epsilon: 0.010000000000000023
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 38337
# reward: 5.0
#  epsilon: 0.010000000000000018
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 38630
# reward: 3.0
#  epsilon: 0.010000000000000014
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 38851
# reward: 7.0
#  epsilon: 0.01000000000000001
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 39159
# reward: 3.0
#  epsilon: 0.010000000000000007
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 39385
# reward: 3.0
#  epsilon: 0.010000000000000007
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 39597
# reward: 4.0
#  epsilon: 0.010000000000000005
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 39872
# reward: 7.0
#  epsilon: 0.010000000000000004
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 40143
# reward: 3.0
#  epsilon: 0.010000000000000004
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 40355
# reward: 4.0
#  epsilon: 0.010000000000000002
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 40598
# reward: 3.0
#  epsilon: 0.010000000000000002
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 40810
# reward: 4.0
#  epsilon: 0.010000000000000002
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 41073
# reward: 4.0
#  epsilon: 0.010000000000000002
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 41334
# reward: 9.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 41803
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 42373
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 42696
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 42955
# reward: 3.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 43167
# reward: 7.0
# ...
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 137977
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 138247
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 138521
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 138797
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 139129
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 139469
# reward: 7.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 139890
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 140164
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 140475
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 140857
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 141155
# reward: 2.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 141347
# reward: 7.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 142130
# reward: 9.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 142513
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 142829
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 143160
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 143496
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 143846
# reward: 2.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 144092
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 144456
# reward: 8.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 144797
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 145093
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 145341
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 145851
# reward: 11.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 146316
# reward: 8.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 146615
# reward: 9.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 147126
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 147481
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 147753
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 148070
# reward: 7.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 149116
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 149411
# reward: 2.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 149595
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 149883
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 150127
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 151930
# reward: 2.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 152116
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 152472
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 152811
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 153110
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 153397
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 153667
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 154126
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 154973
# reward: 8.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 155394
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 155686
# reward: 3.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 155907
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 156259
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 156540
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 156877
# reward: 7.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 157234
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 157561
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 157837
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 158108
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 158394
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 158727
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 159128
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 159424
# reward: 5.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 159709
# reward: 6.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 160051
# reward: 4.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: 160488
# reward: 7.0
#  epsilon: 0.01
#  lenMemory: 100000
#  capacityMemory: 100000
#  steps: